# %%
import matplotlib.pyplot as plt
import yfinance as yf

# %%
# List of cryptocurrency tickers
tickers = ["BTC-USD", "LTC-USD", "BNB-USD", "SOL-USD", "XRP-USD"]

# Download minute-level data
crypto_data = yf.download(tickers, start="2024-08-25", end="2024-08-31", interval="1m")
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
# Calculate additional features for each ticker
for ticker in tickers:
    # Calculate 10-period Simple Moving Average (SMA)
    crypto_data[(ticker, 'SMA_10')] = crypto_data['Close'][ticker].rolling(window=10).mean()

    # Calculate 10-period Exponential Moving Average (EMA)
    crypto_data[(ticker, 'EMA_10')] = crypto_data['Close'][ticker].ewm(span=10, adjust=False).mean()

    # Calculate Relative Strength Index (RSI)
    delta = crypto_data['Close'][ticker].diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=14).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=14).mean()
    RS = gain / loss
    crypto_data[(ticker, 'RSI')] = 100 - (100 / (1 + RS))

    # Calculate Bollinger Bands
    crypto_data[(ticker, 'MA20')] = crypto_data['Close'][ticker].rolling(window=20).mean()
    std = crypto_data['Close'][ticker].rolling(window=20).std()
    crypto_data[(ticker, 'Upper_Band')] = crypto_data[(ticker, 'MA20')] + (std * 2)
    crypto_data[(ticker, 'Lower_Band')] = crypto_data[(ticker, 'MA20')] - (std * 2)

    # Calculate MACD (Moving Average Convergence Divergence)
    crypto_data[(ticker, 'EMA_12')] = crypto_data['Close'][ticker].ewm(span=12, adjust=False).mean()
    crypto_data[(ticker, 'EMA_26')] = crypto_data['Close'][ticker].ewm(span=26, adjust=False).mean()
    crypto_data[(ticker, 'MACD')] = crypto_data[(ticker, 'EMA_12')] - crypto_data[(ticker, 'EMA_26')]
    crypto_data[(ticker, 'Signal_Line')] = crypto_data[(ticker, 'MACD')].ewm(span=9, adjust=False).mean()

# Flatten the MultiIndex columns to make it easier to work with
crypto_data.columns = ['_'.join(col) for col in crypto_data.columns]

# Display the data with additional features
print(crypto_data.head())
# Out:
#                            Adj Close_BNB-USD  Adj Close_BTC-USD
# Datetime
# 2024-08-25 00:00:00+00:00         580.807617       64178.707031  \
# 2024-08-25 00:01:00+00:00         580.760010                NaN
# 2024-08-25 00:02:00+00:00         580.788452       64172.367188
# 2024-08-25 00:03:00+00:00         581.002136       64213.546875
# 2024-08-25 00:04:00+00:00         581.627380       64234.714844
#
#                            Adj Close_LTC-USD  Adj Close_SOL-USD
# Datetime
# 2024-08-25 00:00:00+00:00          66.582848         160.739120  \
# 2024-08-25 00:01:00+00:00          66.585289         160.689697
# 2024-08-25 00:02:00+00:00          66.595711         160.597580
# 2024-08-25 00:03:00+00:00          66.602997         160.603333
# 2024-08-25 00:04:00+00:00          66.645638         160.500153
#
#                            Adj Close_XRP-USD  Close_BNB-USD  Close_BTC-USD
# Datetime
# 2024-08-25 00:00:00+00:00           0.613117     580.807617   64178.707031  \
# 2024-08-25 00:01:00+00:00           0.612996     580.760010            NaN
# 2024-08-25 00:02:00+00:00           0.612935     580.788452   64172.367188
# 2024-08-25 00:03:00+00:00           0.612874     581.002136   64213.546875
# 2024-08-25 00:04:00+00:00           0.612679     581.627380   64234.714844
#
#                            Close_LTC-USD  Close_SOL-USD  Close_XRP-USD  ...
# Datetime                                                                ...
# 2024-08-25 00:00:00+00:00      66.582848     160.739120       0.613117  ...  \
# 2024-08-25 00:01:00+00:00      66.585289     160.689697       0.612996  ...
# 2024-08-25 00:02:00+00:00      66.595711     160.597580       0.612935  ...
# 2024-08-25 00:03:00+00:00      66.602997     160.603333       0.612874  ...
# 2024-08-25 00:04:00+00:00      66.645638     160.500153       0.612679  ...
#
#                            XRP-USD_SMA_10  XRP-USD_EMA_10  XRP-USD_RSI
# Datetime
# 2024-08-25 00:00:00+00:00             NaN        0.613117          NaN  \
# 2024-08-25 00:01:00+00:00             NaN        0.613095          NaN
# 2024-08-25 00:02:00+00:00             NaN        0.613066          NaN
# 2024-08-25 00:03:00+00:00             NaN        0.613031          NaN
# 2024-08-25 00:04:00+00:00             NaN        0.612967          NaN
#
#                            XRP-USD_MA20  XRP-USD_Upper_Band
# Datetime
# 2024-08-25 00:00:00+00:00           NaN                 NaN  \
# 2024-08-25 00:01:00+00:00           NaN                 NaN
# 2024-08-25 00:02:00+00:00           NaN                 NaN
# 2024-08-25 00:03:00+00:00           NaN                 NaN
# 2024-08-25 00:04:00+00:00           NaN                 NaN
#
#                            XRP-USD_Lower_Band  XRP-USD_EMA_12  XRP-USD_EMA_26
# Datetime
# 2024-08-25 00:00:00+00:00                 NaN        0.613117        0.613117  \
# 2024-08-25 00:01:00+00:00                 NaN        0.613098        0.613108
# 2024-08-25 00:02:00+00:00                 NaN        0.613073        0.613095
# 2024-08-25 00:03:00+00:00                 NaN        0.613042        0.613079
# 2024-08-25 00:04:00+00:00                 NaN        0.612987        0.613049
#
#                            XRP-USD_MACD  XRP-USD_Signal_Line
# Datetime
# 2024-08-25 00:00:00+00:00      0.000000             0.000000
# 2024-08-25 00:01:00+00:00     -0.000010            -0.000002
# 2024-08-25 00:02:00+00:00     -0.000022            -0.000006
# 2024-08-25 00:03:00+00:00     -0.000036            -0.000012
# 2024-08-25 00:04:00+00:00     -0.000063            -0.000022
#
# [5 rows x 80 columns]

# %%
# List of top 10 NASDAQ stocks
tickers = ["AAPL", "MSFT", "AMZN", "GOOGL", "META", "TSLA", "NVDA", "PYPL", "ADBE", "NFLX"]

# Download minute-level data
stocks_data = yf.download(tickers, start="2024-08-25", end="2024-08-31", interval="5m")

# Calculate additional features for each stock
for ticker in tickers:
    # Calculate 10-period Simple Moving Average (SMA)
    stocks_data[(ticker, 'SMA_10')] = stocks_data['Close'][ticker].rolling(window=10).mean()

    # Calculate 10-period Exponential Moving Average (EMA)
    stocks_data[(ticker, 'EMA_10')] = stocks_data['Close'][ticker].ewm(span=10, adjust=False).mean()

    # Calculate Relative Strength Index (RSI)
    delta = stocks_data['Close'][ticker].diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=14).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=14).mean()
    RS = gain / loss
    stocks_data[(ticker, 'RSI')] = 100 - (100 / (1 + RS))

    # Calculate Bollinger Bands
    stocks_data[(ticker, 'MA20')] = stocks_data['Close'][ticker].rolling(window=20).mean()
    std = stocks_data['Close'][ticker].rolling(window=20).std()
    stocks_data[(ticker, 'Upper_Band')] = stocks_data[(ticker, 'MA20')] + (std * 2)
    stocks_data[(ticker, 'Lower_Band')] = stocks_data[(ticker, 'MA20')] - (std * 2)

    # Calculate MACD (Moving Average Convergence Divergence)
    stocks_data[(ticker, 'EMA_12')] = stocks_data['Close'][ticker].ewm(span=12, adjust=False).mean()
    stocks_data[(ticker, 'EMA_26')] = stocks_data['Close'][ticker].ewm(span=26, adjust=False).mean()
    stocks_data[(ticker, 'MACD')] = stocks_data[(ticker, 'EMA_12')] - stocks_data[(ticker, 'EMA_26')]
    stocks_data[(ticker, 'Signal_Line')] = stocks_data[(ticker, 'MACD')].ewm(span=9, adjust=False).mean()

# Flatten the MultiIndex columns to make it easier to work with
stocks_data.columns = ['_'.join(col) for col in stocks_data.columns]

# Display the first few rows of the data with additional features
print(stocks_data.head())

# Plot an example for AAPL (Apple Inc.)
plt.figure(figsize=(12, 6))
plt.plot(stocks_data['AAPL_Close'], label='AAPL Close Price')
plt.plot(stocks_data['AAPL_SMA_10'], label='AAPL 10-period SMA')
plt.legend()
plt.title('AAPL Close Price and 10-period SMA')
plt.show()
# Out:
# [*********************100%***********************]  10 of 10 completed
#
# 2 Failed downloads:
# ['AMZN', 'NFLX']: ConnectionError(ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')))
#                            Adj Close_AAPL  Adj Close_ADBE  Adj Close_AMZN
# 2024-08-26 13:30:00+00:00      226.860001      559.059998             NaN  \
# 2024-08-26 13:35:00+00:00      226.699997      559.700012             NaN
# 2024-08-26 13:40:00+00:00      226.544907      559.119995             NaN
# 2024-08-26 13:45:00+00:00      226.121002      559.119995             NaN
# 2024-08-26 13:50:00+00:00      226.399994      559.150024             NaN
#
#                            Adj Close_GOOGL  Adj Close_META  Adj Close_MSFT
# 2024-08-26 13:30:00+00:00       167.139999      526.729980      417.040009  \
# 2024-08-26 13:35:00+00:00       166.395004      524.830017      416.325012
# 2024-08-26 13:40:00+00:00       166.089996      521.622009      415.579987
# 2024-08-26 13:45:00+00:00       165.699997      521.210022      414.790009
# 2024-08-26 13:50:00+00:00       165.735001      521.919983      415.255005
#
#                            Adj Close_NFLX  Adj Close_NVDA  Adj Close_PYPL
# 2024-08-26 13:30:00+00:00             NaN      130.589996       71.809998  \
# 2024-08-26 13:35:00+00:00             NaN      130.729996       72.209999
# 2024-08-26 13:40:00+00:00             NaN      130.554993       72.419998
# 2024-08-26 13:45:00+00:00             NaN      129.714996       72.199997
# 2024-08-26 13:50:00+00:00             NaN      128.960007       72.209999
#
#                            Adj Close_TSLA  ...  NFLX_SMA_10  NFLX_EMA_10
# 2024-08-26 13:30:00+00:00      216.820007  ...          NaN          NaN  \
# 2024-08-26 13:35:00+00:00      217.419998  ...          NaN          NaN
# 2024-08-26 13:40:00+00:00      217.302597  ...          NaN          NaN
# 2024-08-26 13:45:00+00:00      217.440002  ...          NaN          NaN
# 2024-08-26 13:50:00+00:00      216.776093  ...          NaN          NaN
#
#                            NFLX_RSI  NFLX_MA20  NFLX_Upper_Band
# 2024-08-26 13:30:00+00:00       NaN        NaN              NaN  \
# 2024-08-26 13:35:00+00:00       NaN        NaN              NaN
# 2024-08-26 13:40:00+00:00       NaN        NaN              NaN
# 2024-08-26 13:45:00+00:00       NaN        NaN              NaN
# 2024-08-26 13:50:00+00:00       NaN        NaN              NaN
#
#                            NFLX_Lower_Band  NFLX_EMA_12  NFLX_EMA_26
# 2024-08-26 13:30:00+00:00              NaN          NaN          NaN  \
# 2024-08-26 13:35:00+00:00              NaN          NaN          NaN
# 2024-08-26 13:40:00+00:00              NaN          NaN          NaN
# 2024-08-26 13:45:00+00:00              NaN          NaN          NaN
# 2024-08-26 13:50:00+00:00              NaN          NaN          NaN
#
#                            NFLX_MACD  NFLX_Signal_Line
# 2024-08-26 13:30:00+00:00        NaN               NaN
# 2024-08-26 13:35:00+00:00        NaN               NaN
# 2024-08-26 13:40:00+00:00        NaN               NaN
# 2024-08-26 13:45:00+00:00        NaN               NaN
# 2024-08-26 13:50:00+00:00        NaN               NaN
#
# [5 rows x 160 columns]
# /var/folders/wr/rq4bfhkj6h56q645ftw89wtm0000gn/T/ipykernel_98513/2834638902.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_data[(ticker, 'RSI')] = 100 - (100 / (1 + RS))
# /var/folders/wr/rq4bfhkj6h56q645ftw89wtm0000gn/T/ipykernel_98513/2834638902.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_data[(ticker, 'MA20')] = stocks_data['Close'][ticker].rolling(window=20).mean()
# /var/folders/wr/rq4bfhkj6h56q645ftw89wtm0000gn/T/ipykernel_98513/2834638902.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_data[(ticker, 'Upper_Band')] = stocks_data[(ticker, 'MA20')] + (std * 2)
# /var/folders/wr/rq4bfhkj6h56q645ftw89wtm0000gn/T/ipykernel_98513/2834638902.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_data[(ticker, 'Lower_Band')] = stocks_data[(ticker, 'MA20')] - (std * 2)
# /var/folders/wr/rq4bfhkj6h56q645ftw89wtm0000gn/T/ipykernel_98513/2834638902.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_data[(ticker, 'EMA_12')] = stocks_data['Close'][ticker].ewm(span=12, adjust=False).mean()
# /var/folders/wr/rq4bfhkj6h56q645ftw89wtm0000gn/T/ipykernel_98513/2834638902.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_data[(ticker, 'EMA_26')] = stocks_data['Close'][ticker].ewm(span=26, adjust=False).mean()
# /var/folders/wr/rq4bfhkj6h56q645ftw89wtm0000gn/T/ipykernel_98513/2834638902.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_data[(ticker, 'MACD')] = stocks_data[(ticker, 'EMA_12')] - stocks_data[(ticker, 'EMA_26')]
# /var/folders/wr/rq4bfhkj6h56q645ftw89wtm0000gn/T/ipykernel_98513/2834638902.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_data[(ticker, 'Signal_Line')] = stocks_data[(ticker, 'MACD')].ewm(span=9, adjust=False).mean()
# /var/folders/wr/rq4bfhkj6h56q645ftw89wtm0000gn/T/ipykernel_98513/2834638902.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_data[(ticker, 'SMA_10')] = stocks_data['Close'][ticker].rolling(window=10).mean()
# /var/folders/wr/rq4bfhkj6h56q645ftw89wtm0000gn/T/ipykernel_98513/2834638902.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_data[(ticker, 'EMA_10')] = stocks_data['Close'][ticker].ewm(span=10, adjust=False).mean()
# /var/folders/wr/rq4bfhkj6h56q645ftw89wtm0000gn/T/ipykernel_98513/2834638902.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_data[(ticker, 'RSI')] = 100 - (100 / (1 + RS))
# /var/folders/wr/rq4bfhkj6h56q645ftw89wtm0000gn/T/ipykernel_98513/2834638902.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_data[(ticker, 'MA20')] = stocks_data['Close'][ticker].rolling(window=20).mean()
# /var/folders/wr/rq4bfhkj6h56q645ftw89wtm0000gn/T/ipykernel_98513/2834638902.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_data[(ticker, 'Upper_Band')] = stocks_data[(ticker, 'MA20')] + (std * 2)
# /var/folders/wr/rq4bfhkj6h56q645ftw89wtm0000gn/T/ipykernel_98513/2834638902.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_data[(ticker, 'Lower_Band')] = stocks_data[(ticker, 'MA20')] - (std * 2)
# /var/folders/wr/rq4bfhkj6h56q645ftw89wtm0000gn/T/ipykernel_98513/2834638902.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_data[(ticker, 'EMA_12')] = stocks_data['Close'][ticker].ewm(span=12, adjust=False).mean()
# /var/folders/wr/rq4bfhkj6h56q645ftw89wtm0000gn/T/ipykernel_98513/2834638902.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_data[(ticker, 'EMA_26')] = stocks_data['Close'][ticker].ewm(span=26, adjust=False).mean()
# /var/folders/wr/rq4bfhkj6h56q645ftw89wtm0000gn/T/ipykernel_98513/2834638902.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_data[(ticker, 'MACD')] = stocks_data[(ticker, 'EMA_12')] - stocks_data[(ticker, 'EMA_26')]
# /var/folders/wr/rq4bfhkj6h56q645ftw89wtm0000gn/T/ipykernel_98513/2834638902.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   stocks_data[(ticker, 'Signal_Line')] = stocks_data[(ticker, 'MACD')].ewm(span=9, adjust=False).mean()
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.2/envs/timeseries/lib/python3.11/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/.pyenv/versions/3.11.2/envs/timeseries/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.pyenv/versions/3.11.2/envs/timeseries/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'AAPL_Close'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 42
#      40 # Plot an example for AAPL (Apple Inc.)
#      41 plt.figure(figsize=(12, 6))
# ---> 42 plt.plot(stocks_data['AAPL_Close'], label='AAPL Close Price')
#      43 plt.plot(stocks_data['AAPL_SMA_10'], label='AAPL 10-period SMA')
#      44 plt.legend()
#
# File ~/.pyenv/versions/3.11.2/envs/timeseries/lib/python3.11/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/.pyenv/versions/3.11.2/envs/timeseries/lib/python3.11/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'AAPL_Close'
